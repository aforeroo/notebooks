# %% [markdown]
# # Manejo de archivos
#
# se hablara de manipulacion de archivos de texto. Para manejo y manipulacion de archivos binarios, ver el material de la clase de computacion cientifica
#
# ## Modos de apertura
#
# - r --> Lectura/Read
# - w --> Sobreescribir/remplazar/Write
# - a --> Agregar al final / Append over executions
#
# los anteriores son los basicos pero hay modos intermedios los cuales son:
#
# - r  -> Solo lectura
# - r+ -> Lectura y escritura
# - w -> Solo escritura. Sobre escribe el archivo si existe. Crea el archivo si no existe
# - w+ -> Escritura y lectura. Sobre escribe el archivo si existe. Crea el archivo si no existe
# - a -> Añadido (agregar contenido). Crea el archivo si éste no existe
# - a+ -> Añadido (agregar contenido) y lectura. Crea el archivo si éste no existe

# %%
# FORMATO PARA ABRIR UN ARCHIVO EN PYTHON
with open('ruta/del/archivo', 'codigo-modo', encoding='utf-8') as f:
    #hacer algo con el archivo

# %% [markdown]
# la palabra clave `with` es un manejador contextual, que controla el flujo de lectura/escritura del archivo y si algo falla el archivo no se va a corromper. el `enconding='utf-8'` sirve para que se soporten caracteres especiales en la mayoria de alfabetos
