# %%
import pandas as pd

file_path = 'data-housing/melb_data.csv'

housing_data = pd.read_csv(file_path)

housing_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# The results show 8 numbers for each column in your original dataset. The first number, the count, shows how many rows have non-missing values.
#
# Missing values arise for many reasons. For example, the size of the 2nd bedroom wouldn't be collected when surveying a 1 bedroom house. We'll come back to the topic of missing data.
#
# The second value is the mean, which is the average. Under that, std is the standard deviation, which measures how numerically spread out the values are.
#
# To interpret the min, 25%, 50%, 75% and max values, imagine sorting each column from lowest to highest value. The first (smallest) value is the min. If you go a quarter way through the list, you'll find a number that is bigger than 25% of the values and smaller than 75% of the values. That is the 25% value (pronounced "25th percentile"). The 50th and 75th percentiles are defined analogously, and the max is the largest number.

# %% [markdown]
# # Your first ML Model
#
# We'll start by picking a few variables using our intuition. Later courses will show you statistical techniques to automatically prioritize variables.
#
# por ahora se va a eliminar filas que tengan columnas con missing values. si las hay

# %%
housing_data = housing_data.dropna(axis=0)
housing_data.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# ## Prediction target
#
# es una de las variables en conjunto de datos de entrenamiento y que sera el valor a predecir cuando al modelo se le pase un conjunto de entradas para que este categorice o estime su valor

# %%
y = housing_data['Price']

# %% [markdown]
# ## Choosing "Features" - Feature Engineering
#
# los parametros que eligamos importan, no todos pueden estar relacionados al valor a predecir (o al menos no de forma evidente). seleccionar muchos features puede provocar over-fittning, que significa que el modelo es muy especifico y no sirve para generalizar y por tanto no sirve para predecir. O si se eligen pocos features se puede crear un sesgo y un modelo muy generico que tendra metricas de prediccion correcta muy bajas

# %%
features = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 'YearBuilt']

X = housing_data[features]

X.describe()
# Out:
#              Rooms     Bathroom      Landsize  BuildingArea    YearBuilt
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940    141.568645  1964.081988
# std       0.971079     0.711362    897.449881     90.834824    38.105673
# min       1.000000     1.000000      0.000000      0.000000  1196.000000
# 25%       2.000000     1.000000    152.000000     91.000000  1940.000000
# 50%       3.000000     1.000000    373.000000    124.000000  1970.000000
# 75%       4.000000     2.000000    628.000000    170.000000  2000.000000
# max       8.000000     8.000000  37000.000000   3112.000000  2018.000000

# %% [markdown]
# ## Building the Model
#
# The steps to building and using a model are:
#
# - Define: What type of model will it be? A decision tree? Some other type of model? Some other parameters of the model type are specified too.
#
# - Fit: Capture patterns from provided data. This is the heart of modeling.
#
# - Predict: Just what it sounds like
#
# - Evaluate: Determine how accurate the model's predictions are.
#
#
# Here is an example of defining a decision tree model with scikit-learn and fitting it with the features and target variable

# %%
from sklearn.tree import DecisionTreeRegressor as DTR

housing_model = DTR(random_state=1)
# algunos modelos usan procesos aleatorios en la etapa de entrenamiento o fitting
# definir un random_state o semilla va a garantizar la reproductibilidad de una instancia del modelo, eso si, usanoo los mismos datos de entrenamiento
# valores distintos de esta semilla no impactaran en gran medida la calidad del modelo final

housing_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print('Making predictions for the following 5 houses:')
print(X.head(5))
# Out:
# Making predictions for the following 10 houses:
#     Rooms  Bathroom  Landsize  BuildingArea  YearBuilt
# 1       2       1.0     156.0          79.0     1900.0
# 2       3       2.0     134.0         150.0     1900.0
# 4       4       1.0     120.0         142.0     2014.0
# 6       3       2.0     245.0         210.0     1910.0
# 7       2       1.0     256.0         107.0     1890.0
# 9       2       1.0     220.0          75.0     1900.0
# 11      3       2.0     214.0         190.0     2005.0
# 12      2       2.0       0.0          94.0     2009.0
# 15      2       1.0     238.0          97.0     1890.0
# 16      3       2.0     113.0         110.0     1880.0

# %%
print('The predictions of the price are: ')
print(housing_model.predict(X.head(5)))
# Out:
# The predictions of the price are:
# [1035000. 1465000. 1600000. 1876000. 1636000.]

# %% [markdown]
# In practice, you'll want to make predictions for new houses coming on the market rather than the houses we already have prices for. But we'll make predictions for the first few rows of the training data to see how the predict function works.
#
# veamos los precios de estas casas en el conjunto de datos original:

# %%
features_and_target = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 'YearBuilt', 'Price']
X0 =housing_data[features_and_target]
print(X0.head(5))
# Out:
#    Rooms  Bathroom  Landsize  BuildingArea  YearBuilt      Price
# 1      2       1.0     156.0          79.0     1900.0  1035000.0
# 2      3       2.0     134.0         150.0     1900.0  1465000.0
# 4      4       1.0     120.0         142.0     2014.0  1600000.0
# 6      3       2.0     245.0         210.0     1910.0  1876000.0
# 7      2       1.0     256.0         107.0     1890.0  1636000.0
